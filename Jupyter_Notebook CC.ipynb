# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Chih Wei Chao**
# research engineer

# %% [markdown]
# *I am interested in data science because this is the future*

# %% [markdown]
# ### My code in cell 5 is suppose to show 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# This is the horizontal rule example.
# ---
# horizontal rule
#
# **This is the bulleted list example.**
# * My List 1
#     - Nested list item 1
#     - Nested list item 2
# * My List 2
#
# **This is the numberic list example.**
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# **This is the example table.**
#
# |ID|Label|Value|
# |---|:--:|---:|
# |001|Sample 01|True|
# |002|Sample 02|False|
# |003|Sample 03|unknown|
#
# **This is the hyperlink example.**
# [google](http://google.com "Google Search")
#
# **This is the images example.**
# ![image sample](https://sciencenotes.org/wp-content/uploads/2017/05/PeriodicTableWallpaper2017.png "Periodic table")
#
# **This is the code/syntax highlighting example**
# `sample code`
# ```python
# a = "Python syntax highlighting"
# print a
# ```
# **This is the blocked quotes example**
# >This is a sample blockquote
# >
# >Second line of a blockquote
#
# Second part
# >This is another blockquote
# >
# >Second line of second blockquote
#
#
#
# **This is the strikethrough example**
# ~~strikethrough example~~
